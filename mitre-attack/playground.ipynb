# %%
from mitre_attack.client import SemaphoreClient
from pydantic import BaseModel
import os

from typing import Generator, Tuple, List
from pydantic import BaseModel
import pandas as pd
from mitre_attack.prompt import SYSTEM_PROMPT, USER_PROMPT
from mitre_attack.models import ModelCreate, VulnerabilityLog
from mitre_attack.utils import random_datetime, add_random_time
from datetime import datetime
import random
from uuid import uuid4

# %%
from mitre_attack.models import VulnerabilityLog


class Technique(BaseModel):
    technique_id: str
    name: str
    description: str

    @property
    def prompt(self) -> str:
        return f"""
        Technique ID: {self.technique_id}
        Name: {self.name}
        Description: {self.description}
        """


class MitreTechnique:
    def __init__(self, df_path: str):
        self.df = pd.read_csv(df_path)
    
    def generate_with_samples(self, n: int = 5) -> Generator[Tuple[Technique, List[Technique]], None, None]:
        """
        Generator that yields technique information with random samples from other techniques.
        
        Args:
            n: Number of random samples from other techniques (default: 5)
            
        Yields:
            Tuple of (technique, samples) where:
                - technique: Technique model of the current technique
                - samples: List of Technique models of n random other techniques
        """

        returned = 0
        for idx, row in self.df.iterrows():
            # Create the main technique object
            technique = Technique(
                technique_id=row['technique_id'],
                name=row['name'],
                description=row['description']
            )
            
            # Get random samples from other techniques (excluding the current one)
            other_techniques = self.df[self.df['technique_id'] != row['technique_id']]
            if len(other_techniques) > 0:
                samples_df = other_techniques.sample(n=min(n, len(other_techniques)))
                samples = [
                    Technique(
                        technique_id=sample_row['technique_id'],
                        name=sample_row['name'],
                        description=sample_row['description']
                    )
                    for _, sample_row in samples_df.iterrows()
                ]
            else:
                samples = []

            returned += 1
            if returned >= n:
                break
            
            yield technique, samples


class SyntheticTechniqueGenerator:
    def __init__(self, client: SemaphoreClient, sampler: MitreTechnique):
        self.client = client
        self.sampler = sampler

    def generate_message_from_technique_and_samples(self, technique: Technique, samples: list[Technique]) -> List[dict[str, str]]:
        return [
            {
                "role": "system",
                "content": SYSTEM_PROMPT
            },
            {
                "role": "user",
                "content": USER_PROMPT.format(required_technique=technique.prompt, possible_techniques="\n".join([sample.prompt for sample in samples]))
            }
        ]

    def generate_messages_list(self, limit: int = 10) -> List[List[dict[str, str]]]:
        messages_list = []
        for technique, samples in self.sampler.generate_with_samples(limit):
            message = self.generate_message_from_technique_and_samples(technique, samples)
            messages_list.append(message)
            messages_list.append(message)
        return messages_list

    def augment_model_creates(self, model_creates: list[ModelCreate]) -> list[VulnerabilityLog]:

        timestamp = random_datetime(datetime(2024, 1, 1), datetime(2025, 11, 22))
        attacker_id = str(uuid4())

        
        vulnerability_logs = []
        for model_create in model_creates:
            try:
                
                # Always update the session id
                session_id = str(uuid4())

                # Change the attacker id most of the time, but not always
                if random.random() < 0.7:
                    attacker_id = str(uuid4())

                
                for step in model_create.exploitation_steps:
                    timestamp = add_random_time(timestamp, 2, 0.5)
                    vulnerability_log = VulnerabilityLog(
                        created_at=timestamp,
                        vulnerability_type=model_create.vulnerability_type,
                        session_id=session_id,
                        attacker_id=attacker_id,
                        technique_id=step.technique_id,
                    )
                    vulnerability_logs.append(vulnerability_log)
            except Exception as e:
                print(f"Error with model create: {e}")
                continue

        return vulnerability_logs


    async def execute(self, limit: int = 10) -> list[VulnerabilityLog]:
        # Generate messages
        messages_list = self.generate_messages_list(limit)

        # Execute messages to make ModelCreate objects

        print(f"Executing {len(messages_list)} messages")
        model_creates = await self.client.batch_parse_completions(model='gpt-5-mini', messages_list=messages_list, response_format=ModelCreate)

        # Convert the ModelCreate objects to VulnerabilityLog objects
        vulnerability_logs = self.augment_model_creates(model_creates)

        return vulnerability_logs

# %%
df = pd.read_csv(".data/parent.csv")
len(df)
# Out:
# 216

# %%
client = SemaphoreClient()
sampler = MitreTechnique(".data/parent.csv")

generator = SyntheticTechniqueGenerator(client, sampler)

logs = await generator.execute(limit=432)
# Out:
# Executing 432 messages
# Making request 0
# Making request 0
# Making request 1
# Making request 1
# Making request 2
# Making request 2
# Making request 3
# Making request 3
# Making request 4
# Making request 4
# Making request 5
# Making request 5
# Making request 6
# Making request 6
# Making request 7
# Making request 7
# Making request 8
# Making request 8
# Making request 9
# Making request 9
# Making request 10
# Making request 10
# Making request 11
# Making request 11
# Making request 12
# Making request 12
# Making request 13
# Making request 13
# Making request 14
# Making request 14
# Making request 15
# Making request 16
# Making request 17
# Making request 18
# Making request 19
# Making request 20
# Making request 21
# Making request 22
# Making request 23
# Making request 24
# Making request 25
# Making request 26
# Making request 27
# Making request 28
# Making request 29
# Making request 30
# Making request 31
# Making request 32
# Making request 33
# Making request 34
# Making request 35
# Making request 36
# Making request 37
# Making request 38
# Making request 39
# Making request 40
# Making request 41
# Making request 42
# Making request 43
# Making request 44
# Making request 45
# Making request 46
# Making request 47
# Making request 48
# Making request 49
# Making request 50
# Making request 51
# Making request 52
# Making request 53
# Making request 54
# Making request 55
# Making request 56
# Making request 57
# Making request 58
# Making request 59
# Making request 60
# Making request 61
# Making request 62
# Making request 63
# Making request 64
# Making request 65
# Making request 66
# Making request 67
# Making request 68
# Making request 69
# Making request 70
# Making request 71
# Making request 72
# Making request 73
# Making request 74
# Making request 75
# Making request 76
# Making request 77
# Making request 78
# Making request 79
# Making request 80
# Making request 81
# Making request 82
# Making request 83
# Making request 84
# Making request 85
# Making request 86
# Making request 87
# Making request 88
# Making request 89
# Making request 90
# Making request 91
# Making request 92
# Making request 93
# Making request 94
# Making request 95
# Making request 96
# Making request 97
# Making request 98
# Making request 99
# Making request 100
# Making request 101
# Making request 102
# Making request 103
# Making request 104
# Making request 105
# Making request 106
# Making request 107
# Making request 108
# Making request 109
# Making request 110
# Making request 111
# Making request 112
# Making request 113
# Making request 114
# Making request 115
# Making request 116
# Making request 117
# Making request 118
# Making request 119
# Making request 120
# Making request 121
# Making request 122
# Making request 123
# Making request 124
# Making request 125
# Making request 126
# Making request 127
# Making request 128
# Making request 129
# Making request 130
# Making request 131
# Making request 132
# Making request 133
# Making request 134
# Making request 135
# Making request 136
# Making request 137
# Making request 138
# Making request 139
# Making request 140
# Making request 141
# Making request 142
# Making request 143
# Making request 144
# Making request 145
# Making request 146
# Making request 147
# Making request 148
# Making request 149
# Making request 150
# Making request 151
# Making request 152
# Making request 153
# Making request 154
# Making request 155
# Making request 156
# Making request 157
# Making request 158
# Making request 159
# Making request 160
# Making request 161
# Making request 162
# Making request 163
# Making request 164
# Making request 165
# Making request 166
# Making request 167
# Making request 168
# Making request 169
# Making request 170
# Making request 171
# Making request 172
# Making request 173
# Making request 174
# Making request 175
# Making request 176
# Making request 177
# Making request 178
# Making request 179
# Making request 180
# Making request 181
# Making request 182
# Making request 183
# Making request 184
# Making request 185
# Making request 186
# Making request 187
# Making request 188
# Making request 189
# Making request 190
# Making request 191
# Making request 192
# Making request 193
# Making request 194
# Making request 195
# Making request 196
# Making request 197
# Making request 198
# Making request 199
# Making request 200
# Making request 201
# Making request 202
# Making request 203
# Making request 204
# Making request 205
# Making request 206
# Making request 207
# Making request 208
# Making request 209
# Making request 210
# Making request 211
# Making request 212
# Making request 213
# Making request 214
# Making request 215
# Making request 216
# Making request 217
# Making request 218
# Making request 219
# Making request 220
# Making request 221
# Making request 222
# Making request 223
# Making request 224
# Making request 225
# Making request 226
# Making request 227
# Making request 228
# Making request 229
# Making request 230
# Making request 231
# Making request 232
# Making request 233
# Making request 234
# Making request 235
# Making request 236
# Making request 237
# Making request 238
# Making request 239
# Making request 240
# Making request 241
# Making request 242
# Making request 243
# Making request 244
# Making request 245
# Making request 246
# Making request 247
# Making request 248
# Making request 249
# Making request 250
# Making request 251
# Making request 252
# Making request 253
# Making request 254
# Making request 255
# Making request 256
# Making request 257
# Making request 258
# Making request 259
# Making request 260
# Making request 261
# Making request 262
# Making request 263
# Making request 264
# Making request 265
# Making request 266
# Making request 267
# Making request 268
# Making request 269
# Making request 270
# Making request 271
# Making request 272
# Making request 273
# Making request 274
# Making request 275
# Making request 276
# Making request 277
# Making request 278
# Making request 279
# Making request 280
# Making request 281
# Making request 282
# Making request 283
# Making request 284
# Making request 285
# Making request 286
# Making request 287
# Making request 288
# Making request 289
# Making request 290
# Making request 291
# Making request 292
# Making request 293
# Making request 294
# Making request 295
# Making request 296
# Making request 297
# Making request 298
# Making request 299
# Making request 300
# Making request 301
# Making request 302
# Making request 303
# Making request 304
# Making request 305
# Making request 306
# Making request 307
# Making request 308
# Making request 309
# Making request 310
# Making request 311
# Making request 312
# Making request 313
# Making request 314
# Making request 315
# Making request 316
# Making request 317
# Making request 318
# Making request 319
# Making request 320
# Making request 321
# Making request 322
# Making request 323
# Making request 324
# Making request 325
# Making request 326
# Making request 327
# Making request 328
# Making request 329
# Making request 330
# Making request 331
# Making request 332
# Making request 333
# Making request 334
# Making request 335
# Making request 336
# Making request 337
# Making request 338
# Making request 339
# Making request 340
# Making request 341
# Making request 342
# Making request 343
# Making request 344
# Making request 345
# Making request 346
# Making request 347
# Making request 348
# Making request 349
# Making request 350
# Making request 351
# Making request 352
# Making request 353
# Making request 354
# Making request 355
# Making request 356
# Making request 357
# Making request 358
# Making request 359
# Making request 360
# Making request 361
# Making request 362
# Making request 363
# Making request 364
# Making request 365
# Making request 366
# Making request 367
# Making request 368
# Making request 369
# Making request 370
# Making request 371
# Making request 372
# Making request 373
# Making request 374
# Making request 375
# Making request 376
# Making request 377
# Making request 378
# Making request 379
# Making request 380
# Making request 381
# Making request 382
# Making request 383
# Making request 384
# Making request 385
# Making request 386
# Making request 387
# Making request 388
# Making request 389
# Making request 390
# Making request 391
# Making request 392
# Making request 393
# Making request 394
# Making request 395
# Making request 396
# Making request 397
# Making request 398
# Making request 399
# Making request 400
# Making request 401
# Making request 402
# Making request 403
# Making request 404
# Making request 405
# Making request 406
# Making request 407
# Making request 408
# Making request 409
# Making request 410
# Making request 411
# Making request 412
# Making request 413
# Making request 414
# Making request 415
# Making request 416
# Making request 417
# Making request 418
# Making request 419
# Making request 420
# Making request 421
# Making request 422
# Making request 423
# Making request 424
# Making request 425
# Making request 426
# Making request 427
# Making request 428
# Making request 429
# Making request 430
# Making request 431
# Request completed 7
# Making request 15
# Request completed 10
# Making request 16
# Request completed 11
# Making request 17
# Request completed 2
# Making request 18
# Request completed 4
# Making request 19
# Request completed 8
# Making request 20
# Request completed 5
# Making request 21
# Request completed 3
# Making request 22
# Request completed 13
# Making request 23
# Request completed 12
# Making request 24
# Request completed 0
# Making request 25
# Request completed 6
# Making request 26
# Request completed 1
# Making request 27
# Request completed 14
# Making request 28
# Request completed 9
# Making request 29
# Request completed 19
# Making request 30
# Request completed 15
# Making request 31
# Request completed 20
# Making request 32
# Request completed 16
# Making request 33
# Request completed 18
# Making request 34
# Request completed 21
# Making request 35
# Request completed 17
# Making request 36
# Request completed 26
# Making request 37
# Request completed 22
# Making request 38
# Request completed 25
# Making request 39
# Request completed 27
# Making request 40
# Request completed 29
# Making request 41
# Request completed 23
# Making request 42
# Request completed 28
# Making request 43
# Request completed 24
# Making request 44
# Request completed 33
# Making request 45
# Request completed 32
# Making request 46
# Request completed 34
# Making request 47
# Request completed 31
# Making request 48
# Request completed 36
# Making request 49
# Request completed 40
# Making request 50
# Request completed 41
# Making request 51
# Request completed 43
# Making request 52
# Request completed 38
# Making request 53
# Request completed 35
# Making request 54
# Request completed 30
# Making request 55
# Request completed 39
# Making request 56
# Request completed 44
# Making request 57
# Request completed 42
# Making request 58
# Request completed 48
# Making request 59
# Request completed 45
# Making request 60
# Request completed 37
# Making request 61
# Request completed 57
# Making request 62
# Request completed 56
# Making request 63
# Request completed 55
# Making request 64
# Request completed 51
# Making request 65
# Request completed 52
# Making request 66
# Request completed 50
# Making request 67
# Request completed 54
# Making request 68
# Request completed 60
# Making request 69
# Request completed 49
# Making request 70
# Request completed 61
# Making request 71
# Request completed 58
# Making request 72
# Request completed 59
# Making request 73
# Request completed 53
# Making request 74
# Request completed 47
# Making request 75
# Request completed 46
# Making request 76
# Request completed 71
# Making request 77
# Request completed 70
# Making request 78
# Request completed 73
# Making request 79
# Request completed 65
# Making request 80
# Request completed 66
# Making request 81
# Request completed 76
# Making request 82
# Request completed 68
# Making request 83
# Request completed 75
# Making request 84
# Request completed 63
# Making request 85
# Request completed 74
# Making request 86
# Request completed 69
# Making request 87
# Request completed 64
# Making request 88
# Request completed 62
# Making request 89
# Request completed 67
# Making request 90
# Request completed 81
# Making request 91
# Request completed 72
# Making request 92
# Request completed 78
# Making request 93
# Request completed 85
# Making request 94
# Request completed 84
# Making request 95
# Request completed 79
# Making request 96
# Request completed 80
# Making request 97
# Request completed 82
# Making request 98
# Request completed 83
# Making request 99
# Request completed 77
# Making request 100
# Request completed 89
# Making request 101
# Request completed 87
# Making request 102
# Request completed 88
# Making request 103
# Request completed 92
# Making request 104
# Request completed 94
# Making request 105
# Request completed 91
# Making request 106
# Request completed 90
# Making request 107
# Request completed 95
# Making request 108
# Request completed 86
# Making request 109
# Request completed 97
# Making request 110
# Request completed 100
# Making request 111
# Request completed 93
# Making request 112
# Request completed 99
# Making request 113
# Request completed 98
# Making request 114
# Request completed 101
# Making request 115
# Request completed 96
# Making request 116
# Request completed 104
# Making request 117
# Request completed 108
# Making request 118
# Request completed 109
# Making request 119
# Request completed 105
# Making request 120
# Request completed 102
# Making request 121
# Request completed 107
# Making request 122
# Request completed 103
# Making request 123
# Request completed 110
# Making request 124
# Request completed 111
# Making request 125
# Request completed 114
# Making request 126
# Request completed 113
# Making request 127
# Request completed 115
# Making request 128
# Request completed 116
# Making request 129
# Request completed 112
# Making request 130
# Request completed 106
# Making request 131
# Request completed 118
# Making request 132
# Request completed 117
# Making request 133
# Request completed 121
# Making request 134
# Request completed 122
# Making request 135
# Request completed 119
# Making request 136
# Request completed 128
# Making request 137
# Request completed 125
# Making request 138
# Request completed 124
# Making request 139
# Request completed 127
# Making request 140
# Request completed 120
# Making request 141
# Request completed 131
# Making request 142
# Request completed 126
# Making request 143
# Request completed 130
# Making request 144
# Request completed 129
# Making request 145
# Request completed 123
# Making request 146
# Request completed 133
# Making request 147
# Request completed 135
# Making request 148
# Request completed 145
# Making request 149
# Request completed 134
# Making request 150
# Request completed 143
# Making request 151
# Request completed 142
# Making request 152
# Request completed 137
# Making request 153
# Request completed 146
# Making request 154
# Request completed 147
# Making request 155
# Request completed 144
# Making request 156
# Request completed 141
# Making request 157
# Request completed 140
# Making request 158
# Request completed 138
# Making request 159
# Request completed 139
# Making request 160
# Request completed 136
# Making request 161
# Request completed 132
# Making request 162
# Request completed 148
# Making request 163
# Request completed 149
# Making request 164
# Request completed 157
# Making request 165
# Request completed 156
# Making request 166
# Request completed 153
# Making request 167
# Request completed 150
# Making request 168
# Request completed 158
# Making request 169
# Request completed 151
# Making request 170
# Request completed 159
# Making request 171
# Request completed 155
# Making request 172
# Request completed 152
# Making request 173
# Request completed 161
# Making request 174
# Request completed 162
# Making request 175
# Request completed 160
# Making request 176
# Request completed 168
# Making request 177
# Request completed 169
# Making request 178
# Request completed 165
# Making request 179
# Request completed 154
# Making request 180
# Request completed 163
# Making request 181
# Request completed 164
# Making request 182
# Request completed 170
# Making request 183
# Request completed 172
# Making request 184
# Request completed 171
# Making request 185
# Request completed 175
# Making request 186
# Request completed 174
# Making request 187
# Request completed 167
# Making request 188
# Request completed 173
# Making request 189
# Request completed 166
# Making request 190
# Request completed 177
# Making request 191
# Request completed 179
# Making request 192
# Request completed 178
# Making request 193
# Request completed 176
# Making request 194
# Request completed 186
# Making request 195
# Request completed 181
# Making request 196
# Request completed 180
# Making request 197
# Request completed 190
# Making request 198
# Request completed 187
# Making request 199
# Request completed 183
# Making request 200
# Request completed 182
# Making request 201
# Request completed 189
# Making request 202
# Request completed 188
# Making request 203
# Request completed 185
# Making request 204
# Request completed 184
# Making request 205
# Request completed 191
# Making request 206
# Request completed 192
# Making request 207
# Request completed 197
# Making request 208
# Request completed 194
# Making request 209
# Request completed 196
# Making request 210
# Request completed 193
# Making request 211
# Request completed 195
# Making request 212
# Request completed 199
# Making request 213
# Request completed 198
# Making request 214
# Request completed 201
# Making request 215
# Request completed 200
# Making request 216
# Request completed 202
# Making request 217
# Request completed 207
# Making request 218
# Request completed 210
# Making request 219
# Request completed 205
# Making request 220
# Request completed 209
# Making request 221
# Request completed 204
# Making request 222
# Request completed 206
# Making request 223
# Request completed 203
# Making request 224
# Request completed 213
# Making request 225
# Request completed 212
# Making request 226
# Request completed 214
# Making request 227
# Request completed 208
# Making request 228
# Request completed 215
# Making request 229
# Request completed 216
# Making request 230
# Request completed 218
# Making request 231
# Request completed 219
# Making request 232
# Request completed 223
# Making request 233
# Request completed 211
# Making request 234
# Request completed 222
# Making request 235
# Request completed 220
# Making request 236
# Request completed 217
# Making request 237
# Request completed 225
# Making request 238
# Request completed 221
# Making request 239
# Request completed 224
# Making request 240
# Request completed 228
# Making request 241
# Request completed 227
# Making request 242
# Request completed 226
# Making request 243
# Request completed 229
# Making request 244
# Request completed 236
# Making request 245
# Request completed 230
# Making request 246
# Request completed 231
# Making request 247
# Request completed 237
# Making request 248
# Request completed 232
# Making request 249
# Request completed 235
# Making request 250
# Request completed 238
# Making request 251
# Request completed 233
# Making request 252
# Request completed 234
# Making request 253
# Request completed 239
# Making request 254
# Request completed 240
# Making request 255
# Request completed 245
# Making request 256
# Request completed 241
# Making request 257
# Request completed 244
# Making request 258
# Request completed 247
# Making request 259
# Request completed 246
# Making request 260
# Request completed 248
# Making request 261
# Request completed 242
# Making request 262
# Request completed 249
# Making request 263
# Request completed 250
# Making request 264
# Request completed 251
# Making request 265
# Request completed 252
# Making request 266
# Request completed 255
# Making request 267
# Request completed 254
# Making request 268
# Request completed 260
# Making request 269
# Request completed 261
# Making request 270
# Request completed 243
# Making request 271
# Request completed 257
# Making request 272
# Request completed 253
# Making request 273
# Request completed 256
# Making request 274
# Request completed 263
# Making request 275
# Request completed 258
# Making request 276
# Request completed 264
# Making request 277
# Request completed 262
# Making request 278
# Request completed 267
# Making request 279
# Request completed 272
# Making request 280
# Request completed 259
# Making request 281
# Request completed 266
# Making request 282
# Request completed 273
# Making request 283
# Request completed 265
# Making request 284
# Request completed 268
# Making request 285
# Request completed 270
# Making request 286
# Request completed 275
# Making request 287
# Request completed 271
# Making request 288
# Request completed 269
# Making request 289
# Request completed 276
# Making request 290
# Request completed 281
# Making request 291
# Request completed 278
# Making request 292
# Request completed 282
# Making request 293
# Request completed 274
# Making request 294
# Request completed 277
# Making request 295
# Request completed 279
# Making request 296
# Request completed 280
# Making request 297
# Request completed 287
# Making request 298
# Request completed 286
# Making request 299
# Request completed 284
# Making request 300
# Request completed 285
# Making request 301
# Request completed 288
# Making request 302
# Request completed 291
# Making request 303
# Request completed 283
# Making request 304
# Request completed 290
# Making request 305
# Request completed 295
# Making request 306
# Request completed 289
# Making request 307
# Request completed 293
# Making request 308
# Request completed 298
# Making request 309
# Request completed 292
# Making request 310
# Request completed 296
# Making request 311
# Request completed 297
# Making request 312
# Request completed 301
# Making request 313
# Request completed 299
# Making request 314
# Request completed 300
# Making request 315
# Request completed 306
# Making request 316
# Request completed 304
# Making request 317
# Request completed 294
# Making request 318
# Request completed 305
# Making request 319
# Request completed 302
# Making request 320
# Request completed 308
# Making request 321
# Request completed 303
# Making request 322
# Request completed 311
# Making request 323
# Request completed 307
# Making request 324
# Request completed 312
# Making request 325
# Request completed 309
# Making request 326
# Request completed 310
# Making request 327
# Request completed 315
# Making request 328
# Request completed 314
# Making request 329
# Request completed 313
# Making request 330
# Request completed 320
# Making request 331
# Request completed 322
# Making request 332
# Request completed 316
# Making request 333
# Request completed 317
# Making request 334
# Request completed 319
# Making request 335
# Request completed 321
# Making request 336
# Request completed 318
# Making request 337
# Request completed 324
# Making request 338
# Request completed 325
# Making request 339
# Request completed 329
# Making request 340
# Request completed 328
# Making request 341
# Request completed 326
# Making request 342
# Request completed 323
# Making request 343
# Request completed 331
# Making request 344
# Request completed 332
# Making request 345
# Request completed 327
# Making request 346
# Request completed 330
# Making request 347
# Request completed 335
# Making request 348
# Request completed 333
# Making request 349
# Request completed 337
# Making request 350
# Request completed 336
# Making request 351
# Request completed 334
# Making request 352
# Request completed 341
# Making request 353
# Request completed 338
# Making request 354
# Request completed 344
# Making request 355
# Request completed 346
# Making request 356
# Request completed 343
# Making request 357
# Request completed 339
# Making request 358
# Request completed 342
# Making request 359
# Request completed 340
# Making request 360
# Request completed 348
# Making request 361
# Request completed 345
# Making request 362
# Request completed 347
# Making request 363
# Request completed 349
# Making request 364
# Request completed 352
# Making request 365
# Request completed 357
# Making request 366
# Request completed 356
# Making request 367
# Request completed 360
# Making request 368
# Request completed 361
# Making request 369
# Request completed 355
# Making request 370
# Request completed 359
# Making request 371
# Request completed 362
# Making request 372
# Request completed 354
# Making request 373
# Request completed 358
# Making request 374
# Request completed 351
# Making request 375
# Request completed 363
# Making request 376
# Request completed 350
# Making request 377
# Request completed 353
# Making request 378
# Request completed 364
# Making request 379
# Request completed 367
# Making request 380
# Request completed 365
# Making request 381
# Request completed 370
# Making request 382
# Request completed 369
# Making request 383
# Request completed 373
# Making request 384
# Request completed 375
# Making request 385
# Request completed 374
# Making request 386
# Request completed 372
# Making request 387
# Request completed 368
# Making request 388
# Request completed 376
# Making request 389
# Request completed 378
# Making request 390
# Request completed 371
# Making request 391
# Request completed 377
# Making request 392
# Request completed 366
# Making request 393
# Request completed 383
# Making request 394
# Request completed 380
# Making request 395
# Request completed 386
# Making request 396
# Request completed 389
# Making request 397
# Request completed 385
# Making request 398
# Request completed 379
# Making request 399
# Request completed 381
# Making request 400
# Request completed 388
# Making request 401
# Request completed 387
# Making request 402
# Request completed 382
# Making request 403
# Request completed 394
# Making request 404
# Request completed 393
# Making request 405
# Request completed 395
# Making request 406
# Request completed 384
# Making request 407
# Request completed 390
# Making request 408
# Request completed 397
# Making request 409
# Request completed 402
# Making request 410
# Request completed 403
# Making request 411
# Request completed 401
# Making request 412
# Request completed 392
# Making request 413
# Request completed 399
# Making request 414
# Request completed 391
# Making request 415
# Request completed 398
# Making request 416
# Request completed 396
# Making request 417
# Request completed 400
# Making request 418
# Request completed 406
# Making request 419
# Request completed 408
# Making request 420
# Request completed 407
# Making request 421
# Request completed 412
# Making request 422
# Request completed 410
# Making request 423
# Request completed 405
# Making request 424
# Request completed 414
# Making request 425
# Request completed 404
# Making request 426
# Request completed 413
# Making request 427
# Request completed 409
# Making request 428
# Request completed 420
# Making request 429
# Request completed 416
# Making request 430
# Request completed 417
# Making request 431
# Request completed 419
# Request completed 422
# Request completed 411
# Request completed 423
# Request completed 421
# Request completed 418
# Request completed 415
# Request completed 425
# Request completed 427
# Request completed 428
# Request completed 424
# Request completed 426
# Request completed 430
# Request completed 429
# Request completed 431

# %%
len(logs)
# Out:
# 3829

# %%
for log in logs:
    log.session_id = log.session_id[10:]

# %%
logs[0]
# Out:
# VulnerabilityLog(technique_id='T1595', id=UUID('4935b846-84a4-4a3d-b2e1-960d39e7a6e7'), created_at=datetime.datetime(2024, 9, 22, 3, 11, 38, 241317), vulnerability_type='broken-function-level-authorization', session_id='5fd-4bb0-bd6c-c28c9aa05e9d', attacker_id='18400763-dcb8-45cf-9a42-05138805572c')

# %%
from typing import Any

def log_to_dict(logs: List[VulnerabilityLog]) -> List[dict[str, Any]]:

    res = []

    for log in logs:
        res.append({
            "id": log.id,
            "base_url": "https://example.com",
            "vulnerability_type": log.vulnerability_type,
            "technique_id": log.technique_id,
            "timestamp": log.created_at,
            "attacker_id": log.attacker_id,
            "session_id": log.session_id,
            "is_synthetic": True,
        })

    return res

df = pd.DataFrame(log_to_dict(logs))
df.to_csv(".data/synthetic_logs.csv", index=False)

# %%
df = df[df['technique_id'].str.startswith('T', na=False)]

# %%
df.to_csv(".data/synthetic_logs.csv", index=False)

# %%
# Update the id column to a new set of uuids
df['id'] = df['id'].apply(lambda x: str(uuid4()))
df.to_csv(".data/synthetic_logs.csv", index=False)
# Out:
# /var/folders/0q/j9hypd8x28q8j95_jd0b_mlm0000gn/T/ipykernel_68166/51112290.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['id'] = df['id'].apply(lambda x: str(uuid4()))
